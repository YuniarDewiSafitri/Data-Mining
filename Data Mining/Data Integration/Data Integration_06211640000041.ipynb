# %% [markdown]
# # TUGAS 1 DATA INTEGRATION

# %% [markdown]
# ## Indikator Kemiskinan dan Kesenjangan Menurut Provinsi Tahun 2008 Berdasarkan Semester

# %% [markdown]
# ### Sumber: Badan Pusat Statistik (BPS)

# %%
import pandas as pd
import numpy as np

# %%
data_x=pd.read_csv("pedesaan1.csv",sep=",")
data_x
# Out:
#                 Provinsi GKM_SM1    GKM_SM2 GKnM_SMT1   GKnM_SM2  \
# 0                   ACEH  353915  362463.34    100825  104778.98
# 1         SUMATERA UTARA  333843  342317.79     87743   93173.79
# 2         SUMATERA BARAT  369087  370529.45     91162   95901.02
# 3                   RIAU  357685   358620.5    114001  119824.94
# 4                  JAMBI  312113  314945.87     86388   86819.11
# 5       SUMATERA SELATAN  289522  291450.87     85005   87600.96
# 6               BENGKULU  356600  356972.92    108824     117037
# 7                LAMPUNG  293926  299041.14     92038   93160.05
# 8   KEP. BANGKA BELITUNG  472431  495542.54    165869  176561.65
# 9              KEP. RIAU  396882  405549.51    131906  137637.64
# 10           DKI JAKARTA       -          -         -          -
# 11            JAWA BARAT  274016  276660.33     90136   91144.48
# 12           JAWA TENGAH  259564  265809.06     88642    89496.8
# ...

# %%
data_y=pd.read_csv("perkotaan1.csv",sep=",")
data_y
# Out:
#                 Provinsi  GKM_SM1    GKM_SM2  GKnM_SMT1   GKnM_SM2  \
# 0                   ACEH   351777  360318.19     134561  136434.18
# 1         SUMATERA UTARA   328225  345167.42     120138  120623.05
# 2         SUMATERA BARAT   356907  367319.03     139235  140237.58
# 3                   RIAU   342425  350004.22     148954  149398.25
# 4                  JAMBI   358637  363152.88     129154  129210.95
# 5       SUMATERA SELATAN   313669  314491.52     124314  126557.47
# 6               BENGKULU   380731  388650.84     136223  142003.98
# 7                LAMPUNG   321620  327530.49     122626  125522.76
# 8   KEP. BANGKA BELITUNG   442588  469429.91     180347  186718.59
# 9              KEP. RIAU   373829  376276.75     190164  194632.97
# 10           DKI JAKARTA   394158  408790.86     198949  198987.31
# 11            JAWA BARAT   263583  266339.96     105097  105920.36
# 12           JAWA TENGAH   254959  259615.71      98281   99910.20
# ...

# %%
data=pd.merge(data_x, data_y, on="Provinsi")
data
# Out:
#                 Provinsi GKM_SM1_x  GKM_SM2_x GKnM_SMT1_x GKnM_SM2_x  \
# 0                   ACEH    353915  362463.34      100825  104778.98
# 1         SUMATERA UTARA    333843  342317.79       87743   93173.79
# 2         SUMATERA BARAT    369087  370529.45       91162   95901.02
# 3                   RIAU    357685   358620.5      114001  119824.94
# 4                  JAMBI    312113  314945.87       86388   86819.11
# 5       SUMATERA SELATAN    289522  291450.87       85005   87600.96
# 6               BENGKULU    356600  356972.92      108824     117037
# 7                LAMPUNG    293926  299041.14       92038   93160.05
# 8   KEP. BANGKA BELITUNG    472431  495542.54      165869  176561.65
# 9              KEP. RIAU    396882  405549.51      131906  137637.64
# 10           DKI JAKARTA         -          -           -          -
# 11            JAWA BARAT    274016  276660.33       90136   91144.48
# 12           JAWA TENGAH    259564  265809.06       88642    89496.8
# ...
